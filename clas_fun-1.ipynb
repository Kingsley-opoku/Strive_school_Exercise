# %%
class Strive_exercise():

    def __init__(self, num=10):
        pass



    def print_pyramid(num):
   
        string='#'
        for number in range(num+1):
            print(string*number)
    
    def non_duplicated_challenge (num):

        '''Non Duplicated Challenge:
        this c function that receives a list of numbers and returns the non-duplicated number:

i. e non_duplicated_challenge([1, 1, 2, 2, 3, 5, 5, 6, 6]) outputs 3

i. e. non_duplicated_challenge([1, 2, 2, 3, 3]) outputs 1
'''
        list_num=[]

        for i in num:
            if list_num.count(i) > 1:
                pass
            else:
                list_num.append(i)
            return list_num

    def countdown(Num):
         # counting from height to the lowerst value in the range of numbers
        count= Num
        for x in range(Num+1):
            if x!=0:
                count-=1
            if count==0:
                print("Blast off!")
                break
        
        return count


    def divisible_by_3(num):
        """
    a = [2, 4, 6, 12, 15, 99, 100]
    6
    12
    15
    99
    """
        for numbers in num:
            if numbers%3==0:
                return numbers
    
    
    def fibonacci(num):
        """
    Fibonacci sequence up to 22 :
    0 , 1 , 1 , 2 , 3 , 5 , 8 , 13 , 21
    """
     # first two terms
        n1, n2 = 0, 1
        count = 0

        # check if the number of terms is valid
        if num <= 0:
            print("It is not valid")
    # if there is only one term, return n1
        elif num == 1:
            print(n1)
# generate fibonacci sequence
        else:
            print("Fibonacci sequence:")
        while count < num:
            print(n1)
            nth = n1 + n2
       # update values
            n1 = n2
            n2 = nth
            count += 1
        
        return
