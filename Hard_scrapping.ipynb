# %%
import requests
from bs4 import BeautifulSoup
import datetime
import pandas as pd

# %%
page="https://weather.com/weather/tenday/l/San+Francisco+CA?canonicalCityId=dfdaba8cbe3a4d12a8796e1f7b1ccc7174b4b0a2d5ddb1c8566ae9f154fa638c"

# %%
getting_page=requests.get(page)
getting_page
# Out:
# <Response [200]>

# %%
# extracting the required info from the website
extract_data = BeautifulSoup(getting_page.content, "html.parser" )

# %%
days_info = extract_data.find_all("h2" ,class_="DetailsSummary--daypartName--2FBp2")

temp= extract_data.find_all('div',class_="DetailsSummary--temperature--1Syw3") 

descriptions=extract_data.find_all('p', class_="DailyContent--narrative--hplRl")

# %%
# grouping the temperature into low and high
temperatures = []
for i in temp:
    temperatures.append(i.text.replace('°', '').split('/'))
    low_temp=[]
    high_temp=[]
    for j in temperatures:
        low_temp.append(int(j[1]))
        high_temp.append(int(j[0]))

# Exactracting the days from the text 
days_wheather = []
for i in days_info:
    days_wheather.append(i.text)

#extracting the wheather descriptions
low_des = []
high_des=[]
for i in descriptions:
    if i.text.find('Low')==-1:
        high_des.append(i.text)
    else:
        low_des.append(i.text)

# function to convert from Fahrenheit to degree celcius
def temp_celsius(Fahrenheit):
    celcius=[]
    for i in Fahrenheit:
        ce = ((i - 32) * 5 / 9)
        celcius.append(round(ce,2))
    return celcius           

low_temp_celcius=temp_celsius(low_temp) #low temperature in degree celcius

high_temp_celcius=temp_celsius(high_temp) # high temperature in degree celcius




date = (pd.date_range(start= pd.to_datetime("today"), periods=15)        #date                                                   
        .date                                                       
        )

# %%
df=pd.DataFrame ({'date':date,'days_wheather':days_wheather,'low_temp_celcius':low_temp_celcius, 'high_temp_celcius':high_temp_celcius, 'high_des': high_des, 'low_des':low_des} ) 

df
# Out:
#           date days_wheather  low_temp_celcius  high_temp_celcius  \
# 0   2022-03-13         Today              7.22              13.89
# 1   2022-03-14        Mon 14             11.67              16.11
# 2   2022-03-15        Tue 15              7.78              15.56
# 3   2022-03-16        Wed 16              8.89              16.67
# 4   2022-03-17        Thu 17              8.33              16.11
# 5   2022-03-18        Fri 18              9.44              17.22
# 6   2022-03-19        Sat 19              7.22              13.89
# 7   2022-03-20        Sun 20              6.67              15.56
# 8   2022-03-21        Mon 21              8.33              17.22
# 9   2022-03-22        Tue 22              8.33              18.89
# 10  2022-03-23        Wed 23              8.89              20.00
# 11  2022-03-24        Thu 24              8.33              20.56
# 12  2022-03-25        Fri 25              8.33              20.00
# 13  2022-03-26        Sat 26              7.78              18.89
# 14  2022-03-27        Sun 27              7.22              18.33
#
#                                              high_des  \
# 0   Partly cloudy. High 57F. Winds W at 10 to 20 mph.
# 1   Sunshine and clouds mixed. High 61F. Winds SW ...
# 2   Showers in the morning, then cloudy in the aft...
# 3   Partly cloudy skies. High 62F. Winds WNW at 10...
# 4   Morning clouds will give way to sunshine for t...
# 5   Intervals of clouds and sunshine. High 63F. Wi...
# 6   Rain likely. High 57F. Winds WSW at 10 to 20 m...
# 7   Partly cloudy. High around 60F. Winds WNW at 1...
# 8   Except for a few afternoon clouds, mainly sunn...
# 9   A few clouds from time to time. High 66F. Wind...
# 10  Mostly sunny. High 68F. Winds WNW at 10 to 15 ...
# 11  A few clouds early, otherwise mostly sunny. Hi...
# 12  Sunshine along with some cloudy intervals. Hig...
# 13  Sunshine and clouds mixed. High 66F. Winds WNW...
# 14  Partly cloudy skies. High around 65F. Winds WN...
#
#                                               low_des
# 0   Partly cloudy this evening with more clouds fo...
# 1   Cloudy with periods of light rain. Low 53F. Wi...
# 2   Generally fair. Low 46F. Winds WNW at 10 to 15...
# 3   Partly cloudy during the evening followed by c...
# 4   Partly cloudy. Low 47F. Winds WSW at 10 to 15 ...
# 5   Cloudy with occasional showers late at night. ...
# 6   Partly cloudy. Low near 45F. Winds WNW at 10 t...
# 7   A few clouds from time to time. Low 44F. Winds...
# 8   Partly cloudy. Low 47F. Winds WNW at 10 to 15 ...
# 9   Mostly clear skies. Low 47F. Winds WNW at 5 to...
# 10  Partly cloudy. Low 48F. Winds WNW at 10 to 15 ...
# 11  Generally fair. Low 47F. Winds WNW at 5 to 10 ...
# 12  Mainly clear skies. Low 47F. Winds WNW at 10 t...
# 13  Partly cloudy. Low 46F. Winds WNW at 10 to 15 ...
# 14  A few clouds from time to time. Low near 45F. ...
